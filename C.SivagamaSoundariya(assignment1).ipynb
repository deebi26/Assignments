# %%
import pandas as pd

# Load the dataset into a pandas dataframe
df = pd.read_csv('House Price India.csv')

# View the first 5 rows of the dataset
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
display(df)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
#to perform univariate analysis 

#price frequency

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

# Load house price data from CSV file
house_prices_df = pd.read_csv('House Price India.csv')

# Extract house prices as a NumPy array
house_prices = house_prices_df['Price'].values

# Create histogram
plt.hist(house_prices, bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Price Range')
plt.ylabel('Frequency')
plt.title('Distribution of House Prices')

# Show the plot
plt.show()

# %%
#univariate analysis
# price range in boxplot

import matplotlib.pyplot as plt
import pandas as pd

# Read in the data
data = pd.read_csv('House Price India.csv')

# Extract the column of interest
column_of_interest = data['Price']

# Create a box plot
fig, ax = plt.subplots()
ax.boxplot(column_of_interest)
ax.set_title('Box plot of {}'.format('Price'))
ax.set_ylabel('Values')
plt.show()

# %%
#uni-variate analysis
# histogram plot for the frequency of house prices
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('House Price India.csv')

# Choose the price column
prices = df['Price']

# Set the number of bins
num_bins = 20

# Plot the histogram
plt.hist(prices, bins=num_bins)

# Add labels and title
plt.xlabel('House Price')
plt.ylabel('Frequency')
plt.title('Distribution of House Prices')

# Show the plot
plt.show()

# Identify the most frequent price
bin_counts, bin_edges, _ = plt.hist(prices, bins=num_bins)
most_frequent_price = bin_edges[bin_counts.argmax()]
print(f"The most frequent house price is {most_frequent_price}")
# Out:
# The most frequent house price is 78000.0

# %%
#bi-variate analysis
# price with number of floors

import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('House Price India.csv')

# Extract two columns to compare
col1 = df['number of floors']
col2 = df['Price']

# Create scatter plot
plt.scatter(col1, col2)

# Add labels and title
plt.xlabel('number of floors')
plt.ylabel('price')
plt.title('Comparison of number of floors and price')

# Show the plot
plt.show()

# %%
#bivariate analysis
#condition of house with price

import seaborn as sns
import pandas as pd

# Load your data into a Pandas DataFrame
data = pd.read_csv('House Price India.csv')

# Generate a boxplot using Seaborn
sns.boxplot(data=data[['condition of the house', 'Price']])
# Out:
# <Axes: >

# %%
#multivariate analysis
#comparing number of bedroom  and  number of bathroom with price

import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('House Price India.csv')

# Extract columns to compare
col1 = df['number of bedrooms']
col2 = df['number of bathrooms']
col3 = df['Price']

# Create figure with two y-axes
fig, ax1 = plt.subplots()

# Create scatter plot for col1 and col3
ax1.scatter(col3, col1, color='red')
ax1.set_xlabel('bedroom')
ax1.set_ylabel('Price', color='red')

# Create second y-axis for col2
ax2 = ax1.twinx()
ax2.scatter(col3, col2, color='blue')
ax2.set_ylabel('bathroom', color='blue')

# Add title
plt.title('Comparison of bedroom, bathroom, and price')

# Show the plot
plt.show()

# %%
#multivariate analysis
# house price distribution using boxplot

import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('House Price India.csv')

# Create boxplot of prices
plt.boxplot(df['Price'])

# Add labels and title
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of House Prices')

# Show the plot
plt.show()

# %%
#multivariate analysis
import matplotlib.pyplot as plt
import pandas as pd

# load the dataset
data = pd.read_csv('House Price India.csv')

# extract the variables to plot
x = data['Distance from the airport']
y = data['Price']

# plot the data
plt.scatter(x, y)

# add axis labels and title
plt.xlabel('d from airport')
plt.ylabel('Price')
plt.title('Scatter plot of airport and price')

# show the plot
plt.show()

# %%
# Perform descriptive statistics on the dataset

import pandas as pd

# load the dataset
data = pd.read_csv('House Price India.csv')

# get summary statistics
summary = data.describe()

# print summary statistics
print(summary)
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
import pandas as pd

# load the dataset
data = pd.read_csv('House Price India.csv')

# select a column of interest
column_name = 'Price'

# calculate the descriptive statistics
mean = data['Price'].mean()
median = data['Price'].median()
std = data['Price'].std()
min_value = data['Price'].min()
max_value = data['Price'].max()
q1 = data['Price'].quantile(0.25)
q3 = data['Price'].quantile(0.75)

# print the results
print('Mean:', mean)
print('Median:', median)
print('Standard deviation:', std)
print('Minimum value:', min_value)
print('Maximum value:', max_value)
print('25th percentile:', q1)
print('75th percentile:', q3)
# Out:
# Mean: 538932.2183310534
# Median: 450000.0
# Standard deviation: 367532.38080396695
# Minimum value: 78000
# Maximum value: 7700000
# 25th percentile: 320000.0
# 75th percentile: 645000.0

# %%
#handle the missing vales

import pandas as pd

# load the dataset
data = pd.read_csv('House Price India.csv')

# check for missing values
print('Number of missing values:')
print(data.isnull().sum())

# drop rows with missing values
data = data.dropna()

# fill missing values with the mean of the column
data = data.fillna(data.mean())
# Out:
# Number of missing values:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# ...
